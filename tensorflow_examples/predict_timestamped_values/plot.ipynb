# %% [markdown]
# Run a Jupyter Notebook server by
# ```shell
# $ docker run -it --rm -p 8888:8888 -v `pwd`:/notebooks tensorflow/tensorflow:latest-py3
# ```

# %%
import pandas
# %matplotlib inline

# %%
df = pandas.read_csv('dummy_training.csv', parse_dates=['acted_at'], index_col=['acted_at'])

# %%
df.plot.line()
